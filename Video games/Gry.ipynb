# %%
#odczytanie danych

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df_games=pd.read_csv('vgsales.csv')
df_games
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0      2006.0        Sports    Nintendo     41.49     29.02      3.77
# 1      1985.0      Platform    Nintendo     29.08      3.58      6.81
# 2      2008.0        Racing    Nintendo     15.85     12.88      3.79
# 3      2009.0        Sports    Nintendo     15.75     11.01      3.28
# 4      1996.0  Role-Playing    Nintendo     11.27      8.89     10.22
# ...       ...           ...         ...       ...       ...       ...
# 16593  2002.0      Platform       Kemco      0.01      0.00      0.00
# 16594  2003.0       Shooter  Infogrames      0.01      0.00      0.00
# 16595  2008.0        Racing  Activision      0.00      0.00      0.00
# 16596  2010.0        Puzzle    7G//AMES      0.00      0.01      0.00
# 16597  2003.0      Platform     Wanadoo      0.01      0.00      0.00
#
#        Other_Sales  Global_Sales
# 0             8.46         82.74
# 1             0.77         40.24
# 2             3.31         35.82
# 3             2.96         33.00
# 4             1.00         31.37
# ...            ...           ...
# 16593         0.00          0.01
# 16594         0.00          0.01
# 16595         0.00          0.01
# 16596         0.00          0.01
# 16597         0.00          0.01
#
# [16598 rows x 11 columns]

# %% [markdown]
# # Top ten Games

# %%
top_10=df_games.sort_values('Global_Sales',ascending=False).head(10)
top_10
# Out:
#    Rank                       Name Platform    Year         Genre Publisher  \
# 0     1                 Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2          Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3             Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4          Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5   Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
# 5     6                     Tetris       GB  1989.0        Puzzle  Nintendo
# 6     7      New Super Mario Bros.       DS  2006.0      Platform  Nintendo
# 7     8                   Wii Play      Wii  2006.0          Misc  Nintendo
# 8     9  New Super Mario Bros. Wii      Wii  2009.0      Platform  Nintendo
# 9    10                  Duck Hunt      NES  1984.0       Shooter  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37
# 5     23.20      2.26      4.22         0.58         30.26
# 6     11.38      9.23      6.50         2.90         30.01
# 7     14.03      9.20      2.93         2.85         29.02
# 8     14.59      7.06      4.70         2.26         28.62
# 9     26.93      0.63      0.28         0.47         28.31

# %%
#Dla danego roku top 3 gry
years=[year for year, df in df_games.groupby('Year')]
for year in years:
    temp=df_games.loc[df_games['Year']==year].reset_index(drop=True)
    top=temp.sort_values('Global_Sales',ascending=False)['Name'].head(3)
    print(year)
    print(top)
    print('\t')
# Out:
# 1980.0
# 0          Asteroids
# 1    Missile Command
# 2            Kaboom!
# Name: Name, dtype: object
#
# 1981.0
# 0        Pitfall!
# 1         Frogger
# 2    Demon Attack
# Name: Name, dtype: object
#
# 1982.0
# 0        Pac-Man
# 1        Dig Dug
# 2    Mario Bros.
# Name: Name, dtype: object
#
# 1983.0
# 0       Baseball
# 1    Mario Bros.
# 2        Mahjong
# Name: Name, dtype: object
#
# 1984.0
# 0     Duck Hunt
# 1    Excitebike
# 2          Golf
# Name: Name, dtype: object
#
# 1985.0
# 0    Super Mario Bros.
# 1              Kung Fu
# 2               Soccer
# Name: Name, dtype: object
#
# 1986.0
# 0       The Legend of Zelda
# 1    World Class Track Meet
# 2                   Metroid
# Name: Name, dtype: object
#
# 1987.0
# 0    Zelda II: The Adventure of Link
# 1           Mike Tyson's Punch-Out!!
# 2                  Dragon Warrior II
# Name: Name, dtype: object
#
# 1988.0
# 0    Super Mario Bros. 3
# 1    Super Mario Bros. 2
# 2                 Tetris
# Name: Name, dtype: object
#
# 1989.0
# 0              Tetris
# 1    Super Mario Land
# 2           Dr. Mario
# Name: Name, dtype: object
#
# 1990.0
# 0    Super Mario World
# 1            Dr. Mario
# 2             F-1 Race
# Name: Name, dtype: object
#
# 1991.0
# 0    The Legend of Zelda: A Link to the Past
# 1                         Sonic the Hedgehog
# 2                                    SimCity
# Name: Name, dtype: object
#
# 1992.0
# 0      Super Mario Land 2: 6 Golden Coins
# 1                        Super Mario Kart
# 2    Street Fighter II: The World Warrior
# Name: Name, dtype: object
#
# 1993.0
# 0      Super Mario All-Stars
# 1                   Star Fox
# 2    Super Street Fighter II
# Name: Name, dtype: object
#
# 1994.0
# 0               Donkey Kong Country
# 1    Super Mario Land 3: Wario Land
# 2                  Donkey Kong Land
# Name: Name, dtype: object
#
# 1995.0
# 0    Donkey Kong Country 2: Diddy's Kong Quest
# 1               Warcraft II: Tides of Darkness
# 2          Super Mario World 2: Yoshi's Island
# Name: Name, dtype: object
#
# 1996.0
# 0    Pokemon Red/Pokemon Blue
# 1              Super Mario 64
# 2               Mario Kart 64
# Name: Name, dtype: object
#
# 1997.0
# 0         Gran Turismo
# 1    Final Fantasy VII
# 2        GoldenEye 007
# Name: Name, dtype: object
#
# 1998.0
# 0    Pokémon Yellow: Special Pikachu Edition
# 1       The Legend of Zelda: Ocarina of Time
# 2                                   Tekken 3
# Name: Name, dtype: object
#
# 1999.0
# 0    Pokemon Gold/Pokemon Silver
# 1                 Gran Turismo 2
# 2             Final Fantasy VIII
# Name: Name, dtype: object
#
# 2000.0
# 0    Pokémon Crystal Version
# 1           Final Fantasy IX
# 2                   Driver 2
# Name: Name, dtype: object
#
# 2001.0
# 0    Gran Turismo 3: A-Spec
# 1      Grand Theft Auto III
# 2           Final Fantasy X
# Name: Name, dtype: object
#
# 2002.0
# 0      Grand Theft Auto: Vice City
# 1    Pokemon Ruby/Pokemon Sapphire
# 2        Medal of Honor: Frontline
# Name: Name, dtype: object
#
# 2003.0
# 0    Need for Speed Underground
# 1     Mario Kart: Double Dash!!
# 2             Final Fantasy X-2
# Name: Name, dtype: object
#
# 2004.0
# 0        Grand Theft Auto: San Andreas
# 1                       Gran Turismo 4
# 2    Pokemon FireRed/Pokemon LeafGreen
# Name: Name, dtype: object
#
# 2005.0
# 0                                      Nintendogs
# 1                                   Mario Kart DS
# 2    Brain Age: Train Your Brain in Minutes a Day
# Name: Name, dtype: object
#
# 2006.0
# 0               Wii Sports
# 1    New Super Mario Bros.
# 2                 Wii Play
# Name: Name, dtype: object
#
# 2007.0
# 0               Wii Fit
# 1                Halo 3
# 2    Super Mario Galaxy
# Name: Name, dtype: object
#
# 2008.0
# 0             Mario Kart Wii
# 1    Super Smash Bros. Brawl
# 2        Grand Theft Auto IV
# Name: Name, dtype: object
#
# 2009.0
# 0            Wii Sports Resort
# 1    New Super Mario Bros. Wii
# 2                 Wii Fit Plus
# Name: Name, dtype: object
#
# 2010.0
# 0             Kinect Adventures!
# 1    Pokemon Black/Pokemon White
# 2        Call of Duty: Black Ops
# Name: Name, dtype: object
#
# 2011.0
# 0    Call of Duty: Modern Warfare 3
# 1    Call of Duty: Modern Warfare 3
# 2                      Mario Kart 7
# Name: Name, dtype: object
#
# 2012.0
# 0    Call of Duty: Black Ops II
# 1    Call of Duty: Black Ops II
# 2       New Super Mario Bros. 2
# Name: Name, dtype: object
#
# 2013.0
# 0     Grand Theft Auto V
# 1     Grand Theft Auto V
# 2    Pokemon X/Pokemon Y
# Name: Name, dtype: object
#
# 2014.0
# 0                           Grand Theft Auto V
# 1    Pokemon Omega Ruby/Pokemon Alpha Sapphire
# 2               Call of Duty: Advanced Warfare
# Name: Name, dtype: object
#
# 2015.0
# 0       Call of Duty: Black Ops 3
# 1                         FIFA 16
# 2    Star Wars Battlefront (2015)
# Name: Name, dtype: object
#
# 2016.0
# 0                       FIFA 17
# 1    Uncharted 4: A Thief's End
# 2     Tom Clancy's The Division
# Name: Name, dtype: object
#
# 2017.0
# 0    Phantasy Star Online 2 Episode 4: Deluxe Package
# 1    Phantasy Star Online 2 Episode 4: Deluxe Package
# 2                    Brothers Conflict: Precious Baby
# Name: Name, dtype: object
#
# 2020.0
# 0    Imagine: Makeup Artist
# Name: Name, dtype: object

# %%
df_games.groupby('Name').sum()
# Out:
#                                           Rank    Year  NA_Sales  EU_Sales  \
# Name
# '98 Koshien                               4756  1998.0      0.15      0.10
# .hack//G.U. Vol.1//Rebirth                8359  2006.0      0.00      0.00
# .hack//G.U. Vol.2//Reminisce              7109  2006.0      0.11      0.09
# .hack//G.U. Vol.2//Reminisce (jp sales)   8604  2006.0      0.00      0.00
# .hack//G.U. Vol.3//Redemption             8306  2007.0      0.00      0.00
# ...                                        ...     ...       ...       ...
# thinkSMART: Chess for Kids               16417  2011.0      0.01      0.00
# uDraw Studio                               628  2010.0      1.67      0.58
# uDraw Studio: Instant Artist             23363  4022.0      0.09      0.10
# wwe Smackdown vs. Raw 2006                 471     0.0      1.57      1.02
# ¡Shin Chan Flipa en colores!              9137  2007.0      0.00      0.00
#
#                                          JP_Sales  Other_Sales  Global_Sales
# Name
# '98 Koshien                                  0.12         0.03          0.41
# .hack//G.U. Vol.1//Rebirth                   0.17         0.00          0.17
# .hack//G.U. Vol.2//Reminisce                 0.00         0.03          0.23
# .hack//G.U. Vol.2//Reminisce (jp sales)      0.16         0.00          0.16
# .hack//G.U. Vol.3//Redemption                0.17         0.00          0.17
# ...                                           ...          ...           ...
# thinkSMART: Chess for Kids                   0.00         0.00          0.01
# uDraw Studio                                 0.00         0.20          2.46
# uDraw Studio: Instant Artist                 0.00         0.02          0.21
# wwe Smackdown vs. Raw 2006                   0.00         0.41          3.00
# ¡Shin Chan Flipa en colores!                 0.14         0.00          0.14
#
# [11493 rows x 7 columns]

# %%
#sprzedaż po kontynentach, wszechczasów
sales=df_games.groupby('Year').sum()

na_sales=0
eu_sales=0
jp_sales=0


for index,row in sales.iterrows():
    na_sales+=row['NA_Sales']
    eu_sales+=row['EU_Sales']
    jp_sales+=row['JP_Sales']

x=["na_sales","eu_sales","jp_sales"]     
y=[na_sales,eu_sales,jp_sales] 
    
plt.bar(x,y)
plt.show()

# %%
#najpopularnijeszy rodzaj gier

top_genre=df_games.groupby('Genre')['Publisher'].count()
top_genre.sort_values(ascending=False)
# Out:
# Genre
# Action          3309
# Sports          2343
# Misc            1712
# Role-Playing    1486
# Shooter         1308
# Adventure       1282
# Racing          1248
# Platform         884
# Simulation       863
# Fighting         846
# Strategy         678
# Puzzle           581
# Name: Publisher, dtype: int64

# %%
#najpopularniejsza platforma

top_platform=df_games.groupby('Platform')['Publisher'].count()
top_platform.sort_values(ascending=False)
# Out:
# Platform
# PS2     2159
# DS      2156
# PS3     1326
# Wii     1324
# X360    1261
# PSP     1211
# PS      1193
# PC       954
# XB       824
# GBA      796
# GC       556
# 3DS      507
# PSV      411
# PS4      336
# N64      319
# SNES     239
# XOne     213
# SAT      173
# WiiU     143
# 2600     133
# NES       98
# GB        98
# DC        52
# GEN       27
# NG        12
# SCD        6
# WS         6
# 3DO        3
# TG16       2
# PCFX       1
# GG         1
# Name: Publisher, dtype: int64

# %% [markdown]
# # zmiany w czasie

# %%
df_games['count']=1

#konsole w czasie

years=[year for year, df in df_games.groupby('Year')]
platforms=[platform for platform, df in df_games.groupby('Platform')]

x=years
i=0
y=[]
for year in years:
    t=[]
    for platform in platforms:
        k=df_games.loc[(df_games['Platform']==platform)&(df_games['Year']==year)]['Platform'].count()
        t.append(k)

    y.append(t)   

    
for ys in y:
    plt.plot(x,y)
    

# wykres estetyka   
    
    
    
plt.show()

# %%
#rodzaj gry w czasie

years=[year for year, df in df_games.groupby('Year')]
genres=[genre for genre, df in df_games.groupby('Genre')]

x=years
i=0
y=[]
for year in years:
    t=[]
    for genre in genres:
        k=df_games.loc[(df_games['Genre']==genre)&(df_games['Year']==year)]['Genre'].count()
        t.append(k)

    y.append(t)   

    
for ys in y:
    plt.plot(x,y)
    

# wykres estetyka   
    
    
    
plt.show()
