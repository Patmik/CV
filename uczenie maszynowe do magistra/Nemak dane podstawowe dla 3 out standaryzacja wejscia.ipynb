# %% [markdown]
# # Ładowanie danych

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
nemak_raw = pd.read_excel('NEMAK_wybrane.xlsx')

# %%
nemak_raw
# Out:
#         Shift  Czas 1. fazy wtrysku [ms]  Czas 2. fazy wtrysku [ms]  \
# 0         1.0                   0.158952                   0.740157
# 1         1.0                   0.156441                   0.755905
# 2         1.0                   0.151776                   0.779528
# 3         1.0                   0.151058                   0.874016
# 4         1.0                   0.151417                   0.748031
# ...       ...                        ...                        ...
# 158944    0.0                   0.098672                   0.165354
# 158945    0.0                   0.098314                   0.157480
# 158946    0.0                   0.103337                   0.165354
# 158947    0.0                   0.097237                   0.165354
# 158948    0.0                   0.096161                   0.173228
#
#         Czas cyklu [s]  Filtr prózni 2 [mBar]  \
# 0             0.000000               0.016471
# 1             0.246458               0.015882
# 2             0.249323               0.013529
# 3             0.316192               0.015294
# 4             0.210317               0.015882
# ...                ...                    ...
# 158944        0.154752               0.135294
# 158945        0.154752               0.128824
# 158946        0.154593               0.133529
# 158947        0.154752               0.135294
# 158948        0.154752               0.123529
#
#         Grubosc pietki ukladu wlewowego [mm]  Kod formy   Koncentrat [%]  \
# 0                                   0.000534        0.00        0.462963
# 1                                   0.000549        0.00        0.462963
# 2                                   0.000366        0.00        0.462963
# 3                                   1.000000        0.00        0.462963
# 4                                   0.000519        0.00        0.462963
# ...                                      ...         ...             ...
# 158944                              0.000565        0.25        0.481481
# 158945                              0.000565        0.25        0.481481
# 158946                              0.000549        0.25        0.481481
# 158947                              0.000565        0.25        0.481481
# 158948                              0.000549        0.25        0.462963
#
#         Max. cisnienie [Bar]  Max. predkosc wtrysku [m/s]  ...  \
# 0                   0.082418                     0.044467  ...
# 1                   0.080586                     0.044467  ...
# 2                   0.080586                     0.039297  ...
# 3                   0.084249                     0.046536  ...
# 4                   0.080586                     0.041365  ...
# ...                      ...                          ...  ...
# 158944              0.360806                     0.368149  ...
# 158945              0.358974                     0.368149  ...
# 158946              0.360806                     0.368149  ...
# 158947              0.358974                     0.368149  ...
# 158948              0.360806                     0.368149  ...
#
#         Temperatura w obwodzie chlodzenia 6 [°C]  \
# 0                                       0.342105
# 1                                       0.315789
# 2                                       0.368421
# 3                                       0.342105
# 4                                       0.342105
# ...                                          ...
# 158944                                  0.263158
# 158945                                  0.263158
# 158946                                  0.263158
# 158947                                  0.236842
# 158948                                  0.236842
#
#         Temperatura w obwodzie chlodzenia 7 [°C]  \
# 0                                       0.179487
# 1                                       0.282051
# 2                                       0.230769
# 3                                       0.256410
# 4                                       0.256410
# ...                                          ...
# 158944                                  0.230769
# 158945                                  0.230769
# 158946                                  0.230769
# 158947                                  0.230769
# 158948                                  0.230769
#
#         Temperatura wody na wejsciu JetCool [°C]  Wartosc prózni 2 [mBar]  \
# 0                                       0.474293                 0.659243
# 1                                       0.407455                 0.595212
# 2                                       0.474293                 0.610245
# 3                                       0.446015                 0.630290
# 4                                       0.437018                 0.598552
# ...                                          ...                      ...
# 158944                                  0.618252                 0.197105
# 158945                                  0.591260                 0.182628
# 158946                                  0.605398                 0.182071
# 158947                                  0.611825                 0.190980
# 158948                                  0.629820                 0.190980
#
#         Leakage_High  LeakageHighStatus  Wartosc próżni 1&3 corr  \
# 0                NaN                NaN                 0.757412
# 1           0.000000                NaN                 0.698787
# 2           0.000000                NaN                 0.712938
# 3           0.000000                NaN                 0.727763
# 4           0.000000                NaN                 0.702156
# ...              ...                ...                      ...
# 158944      0.002300               GOOD                 0.247978
# 158945      0.002967               GOOD                 0.240566
# 158946      0.003267               GOOD                 0.237871
# 158947      0.002650               GOOD                 0.239218
# 158948      0.004017               GOOD                 0.236523
#
#         Filtr próżni 1&3 corr  Profil próżni 1&3 corr  \
# 0                    0.474747                0.570245
# 1                    0.476010                0.546567
# 2                    0.477904                0.584451
# 3                    0.481376                0.571429
# 4                    0.475694                0.547751
# ...                       ...                     ...
# 158944               0.378472                0.405683
# 158945               0.372475                0.419495
# 158946               0.372790                0.405683
# 158947               0.374369                0.406077
# 158948               0.368371                0.417522
#
#         Termoregulator 3.1&3.2 corr
# 0                          0.061597
# 1                          0.062022
# 2                          0.062022
# 3                          0.062022
# 4                          0.062022
# ...                             ...
# 158944                     0.062872
# 158945                     0.064146
# 158946                     0.065421
# 158947                     0.062872
# 158948                     0.062872
#
# [158949 rows x 50 columns]

# %%
nemak_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158949 entries, 0 to 158948
# Data columns (total 50 columns):
#  #   Column                                     Non-Null Count   Dtype
# ---  ------                                     --------------   -----
#  0   Shift                                      158949 non-null  float64
#  1   Czas 1. fazy wtrysku [ms]                  158949 non-null  float64
#  2   Czas 2. fazy wtrysku [ms]                  158949 non-null  float64
#  3   Czas cyklu [s]                             158949 non-null  float64
#  4   Filtr prózni 2 [mBar]                      158949 non-null  float64
#  5   Grubosc pietki ukladu wlewowego [mm]       158949 non-null  float64
#  6   Kod formy                                  158949 non-null  float64
#  7   Koncentrat [%]                             158949 non-null  float64
#  8   Max. cisnienie [Bar]                       158949 non-null  float64
#  9   Max. predkosc wtrysku [m/s]                158949 non-null  float64
#  10  Opóznienie multiplikacji [ms]              158949 non-null  float64
#  11  Poziom wody w JetCool [mm]                 158949 non-null  float64
#  12  Predkosc 1. fazy wtrysku [m/s]             158949 non-null  float64
#  13  Predkosc 2. fazy wtrysku [m/s]             158949 non-null  float64
#  14  Profil prózni 2 [mBar]                     158949 non-null  float64
#  15  Przeplyw w obwodzie chlodzenia  1 [l]      158949 non-null  float64
#  16  Przeplyw w obwodzie chlodzenia  11 [l]     158949 non-null  float64
#  17  Przeplyw w obwodzie chlodzenia  12 [l]     158949 non-null  float64
#  18  Przeplyw w obwodzie chlodzenia  13 [l]     158949 non-null  float64
#  19  Przeplyw w obwodzie chlodzenia  14 [l]     158949 non-null  float64
#  20  Przeplyw w obwodzie chlodzenia  15 [l]     158949 non-null  float64
#  21  Przeplyw w obwodzie chlodzenia  17 [l]     158949 non-null  float64
#  22  Przeplyw w obwodzie chlodzenia  18 [l]     158949 non-null  float64
#  23  Przeplyw w obwodzie chlodzenia  20 [l]     158949 non-null  float64
#  24  Przeplyw w obwodzie chlodzenia  6 [l]      158949 non-null  float64
#  25  Przeplyw w obwodzie chlodzenia  7 [l]      158949 non-null  float64
#  26  Suw 1. fazy wtrysku [mm]                   158949 non-null  float64
#  27  Suw 2. fazy wtrysku [mm]                   158949 non-null  float64
#  28  Temperatura stopu [°C]                     158949 non-null  float64
#  29  Temperatura termoregulator 2.1 [°C]        158949 non-null  float64
#  30  Temperatura termoregulator 2.2 [°C]        158949 non-null  float64
#  31  Temperatura w obwodzie chlodzenia 1 [°C]   158949 non-null  float64
#  32  Temperatura w obwodzie chlodzenia 11 [°C]  158949 non-null  float64
#  33  Temperatura w obwodzie chlodzenia 12 [°C]  158949 non-null  float64
#  34  Temperatura w obwodzie chlodzenia 13 [°C]  158949 non-null  float64
#  35  Temperatura w obwodzie chlodzenia 14 [°C]  158949 non-null  float64
#  36  Temperatura w obwodzie chlodzenia 15 [°C]  158949 non-null  float64
#  37  Temperatura w obwodzie chlodzenia 17 [°C]  158949 non-null  float64
#  38  Temperatura w obwodzie chlodzenia 18 [°C]  158949 non-null  float64
#  39  Temperatura w obwodzie chlodzenia 20 [°C]  158949 non-null  float64
#  40  Temperatura w obwodzie chlodzenia 6 [°C]   158949 non-null  float64
#  41  Temperatura w obwodzie chlodzenia 7 [°C]   158949 non-null  float64
#  42  Temperatura wody na wejsciu JetCool [°C]   158949 non-null  float64
#  43  Wartosc prózni 2 [mBar]                    158949 non-null  float64
#  44  Leakage_High                               158948 non-null  float64
#  45  LeakageHighStatus                          127547 non-null  object
#  46  Wartosc próżni 1&3 corr                    158949 non-null  float64
#  47  Filtr próżni 1&3 corr                      158949 non-null  float64
#  48  Profil próżni 1&3 corr                     158949 non-null  float64
#  49  Termoregulator 3.1&3.2 corr                158949 non-null  float64
# dtypes: float64(49), object(1)
# memory usage: 60.6+ MB

# %%
good = nemak_raw.loc[nemak_raw['LeakageHighStatus']=='GOOD'].count()[0]
no_good = nemak_raw.loc[nemak_raw['LeakageHighStatus']=='NO GOOD'].count()[0]
reparaible = nemak_raw.loc[nemak_raw['LeakageHighStatus']=='REPARAIBLE'].count()[0]

labels = ['good','no_good','reparaible']
plt.pie([good,no_good,reparaible], labels = labels, autopct='%.2f%%')
plt.show()

# %%
nemak_raw.groupby(['LeakageHighStatus']).count()
# Out:
#                     Shift  Czas 1. fazy wtrysku [ms]  \
# LeakageHighStatus
# GOOD               114076                     114076
# NO GOOD               784                        784
# REPARAIBLE          12687                      12687
#
#                    Czas 2. fazy wtrysku [ms]  Czas cyklu [s]  \
# LeakageHighStatus
# GOOD                                  114076          114076
# NO GOOD                                  784             784
# REPARAIBLE                             12687           12687
#
#                    Filtr prózni 2 [mBar]  \
# LeakageHighStatus
# GOOD                              114076
# NO GOOD                              784
# REPARAIBLE                         12687
#
#                    Grubosc pietki ukladu wlewowego [mm]  Kod formy   \
# LeakageHighStatus
# GOOD                                             114076      114076
# NO GOOD                                             784         784
# REPARAIBLE                                        12687       12687
#
#                    Koncentrat [%]  Max. cisnienie [Bar]  \
# LeakageHighStatus
# GOOD                       114076                114076
# NO GOOD                       784                   784
# REPARAIBLE                  12687                 12687
#
#                    Max. predkosc wtrysku [m/s]  ...  \
# LeakageHighStatus                               ...
# GOOD                                    114076  ...
# NO GOOD                                    784  ...
# REPARAIBLE                               12687  ...
#
#                    Temperatura w obwodzie chlodzenia 20 [°C]  \
# LeakageHighStatus
# GOOD                                                  114076
# NO GOOD                                                  784
# REPARAIBLE                                             12687
#
#                    Temperatura w obwodzie chlodzenia 6 [°C]  \
# LeakageHighStatus
# GOOD                                                 114076
# NO GOOD                                                 784
# REPARAIBLE                                            12687
#
#                    Temperatura w obwodzie chlodzenia 7 [°C]  \
# LeakageHighStatus
# GOOD                                                 114076
# NO GOOD                                                 784
# REPARAIBLE                                            12687
#
#                    Temperatura wody na wejsciu JetCool [°C]  \
# LeakageHighStatus
# GOOD                                                 114076
# NO GOOD                                                 784
# REPARAIBLE                                            12687
#
#                    Wartosc prózni 2 [mBar]  Leakage_High  \
# LeakageHighStatus
# GOOD                                114076        114076
# NO GOOD                                784           784
# REPARAIBLE                           12687         12687
#
#                    Wartosc próżni 1&3 corr  Filtr próżni 1&3 corr  \
# LeakageHighStatus
# GOOD                                114076                 114076
# NO GOOD                                784                    784
# REPARAIBLE                           12687                  12687
#
#                    Profil próżni 1&3 corr  Termoregulator 3.1&3.2 corr
# LeakageHighStatus
# GOOD                               114076                       114076
# NO GOOD                               784                          784
# REPARAIBLE                          12687                        12687
#
# [3 rows x 49 columns]

# %%
114076+784+12687
# Out:
# 127547

# %%
nemak_raw.groupby(['LeakageHighStatus']).describe()['Leakage_High']
# Out:
#                       count      mean       std     min       25%       50%  \
# LeakageHighStatus
# GOOD               114076.0  0.003637  0.002600  0.0000  0.001817  0.002850
# NO GOOD               784.0  0.248962  0.185525  0.0027  0.146244  0.177478
# REPARAIBLE          12687.0  0.034596  0.024226  0.0125  0.017184  0.025150
#
#                         75%       max
# LeakageHighStatus
# GOOD               0.004750  0.012500
# NO GOOD            0.252321  1.000000
# REPARAIBLE         0.043367  0.124985

# %%
nemak_raw.hist(bins=50,figsize=(20,15))
plt.show()

# %%
nemak_raw['Leakage_High'].hist(bins=50,figsize=(20,15))
plt.show()

# %% [markdown]
# # Czyszczenie danych

# %%
clean_nemak_raw = nemak_raw.dropna(how='any')

# %%
clean_nemak_raw.head(10)
# Out:
#     Shift  Czas 1. fazy wtrysku [ms]  Czas 2. fazy wtrysku [ms]  \
# 12    1.0                   0.175099                   0.149606
# 16    1.0                   0.153570                   0.149606
# 17    1.0                   0.160029                   0.149606
# 18    1.0                   0.157158                   0.157480
# 20    1.0                   0.157517                   0.149606
# 22    1.0                   0.157876                   0.149606
# 23    1.0                   0.158593                   0.149606
# 24    1.0                   0.162540                   0.149606
# 25    1.0                   0.152494                   0.141732
# 26    1.0                   0.153570                   0.149606
#
#     Czas cyklu [s]  Filtr prózni 2 [mBar]  \
# 12        0.212864               0.017059
# 16        0.153001               0.012353
# 17        0.153160               0.011765
# 18        0.152683               0.012941
# 20        0.153001               0.014118
# 22        0.152683               0.011176
# 23        0.152523               0.011765
# 24        0.152523               0.017059
# 25        0.152842               0.014706
# 26        0.152842               0.015294
#
#     Grubosc pietki ukladu wlewowego [mm]  Kod formy   Koncentrat [%]  \
# 12                              0.000671         0.0        0.462963
# 16                              0.000610         0.0        0.370370
# 17                              0.000610         0.0        0.425926
# 18                              0.000626         0.0        0.444444
# 20                              0.000656         0.0        0.462963
# 22                              0.000656         0.0        0.296296
# 23                              0.000626         0.0        0.444444
# 24                              0.000656         0.0        0.462963
# 25                              0.000687         0.0        0.462963
# 26                              0.000656         0.0        0.462963
#
#     Max. cisnienie [Bar]  Max. predkosc wtrysku [m/s]  ...  \
# 12              0.366300                     0.357808  ...
# 16              0.366300                     0.367115  ...
# 17              0.364469                     0.368149  ...
# 18              0.364469                     0.368149  ...
# 20              0.362637                     0.357808  ...
# 22              0.360806                     0.368149  ...
# 23              0.364469                     0.367115  ...
# 24              0.362637                     0.368149  ...
# 25              0.360806                     0.368149  ...
# 26              0.360806                     0.368149  ...
#
#     Temperatura w obwodzie chlodzenia 6 [°C]  \
# 12                                  0.315789
# 16                                  0.157895
# 17                                  0.157895
# 18                                  0.157895
# 20                                  0.131579
# 22                                  0.131579
# 23                                  0.131579
# 24                                  0.131579
# 25                                  0.131579
# 26                                  0.131579
#
#     Temperatura w obwodzie chlodzenia 7 [°C]  \
# 12                                  0.282051
# 16                                  0.230769
# 17                                  0.230769
# 18                                  0.230769
# 20                                  0.230769
# 22                                  0.230769
# 23                                  0.230769
# 24                                  0.230769
# 25                                  0.230769
# 26                                  0.230769
#
#     Temperatura wody na wejsciu JetCool [°C]  Wartosc prózni 2 [mBar]  \
# 12                                  0.419023                 0.085746
# 16                                  0.428021                 0.083519
# 17                                  0.425450                 0.125835
# 18                                  0.426735                 0.109131
# 20                                  0.422879                 0.072940
# 22                                  0.424165                 0.092984
# 23                                  0.424165                 0.067372
# 24                                  0.422879                 0.047327
# 25                                  0.421594                 0.098552
# 26                                  0.420308                 0.099666
#
#     Leakage_High  LeakageHighStatus  Wartosc próżni 1&3 corr  \
# 12      0.047934         REPARAIBLE                 0.225741
# 16      0.002850               GOOD                 0.224394
# 17      0.003417               GOOD                 0.258086
# 18      0.001867               GOOD                 0.242588
# 20      0.000000               GOOD                 0.217655
# 22      0.003217               GOOD                 0.224394
# 23      0.001667               GOOD                 0.202830
# 24      0.002233               GOOD                 0.183288
# 25      0.001633               GOOD                 0.228437
# 26      0.002450               GOOD                 0.229784
#
#     Filtr próżni 1&3 corr  Profil próżni 1&3 corr  Termoregulator 3.1&3.2 corr
# 12               0.471907                0.515391                     0.064146
# 16               0.481061                0.503946                     0.063721
# 17               0.485480                0.502368                     0.063297
# 18               0.485164                0.501973                     0.064996
# 20               0.482323                0.500789                     0.064996
# 22               0.476957                0.500000                     0.064996
# 23               0.474116                0.499605                     0.062872
# 24               0.472854                0.498421                     0.064996
# 25               0.481376                0.496843                     0.062872
# 26               0.472538                0.496843                     0.064571
#
# [10 rows x 50 columns]

# %%
clean_nemak_raw.describe()
# Out:
#                Shift  Czas 1. fazy wtrysku [ms]  Czas 2. fazy wtrysku [ms]  \
# count  127547.000000              127547.000000              127547.000000
# mean        0.547571                   0.147266                   0.160813
# std         0.406574                   0.042959                   0.011209
# min         0.000000                   0.000000                   0.118110
# 25%         0.000000                   0.112307                   0.157480
# 50%         0.500000                   0.158952                   0.157480
# 75%         1.000000                   0.176534                   0.165354
# max         1.000000                   0.996412                   0.874016
#
#        Czas cyklu [s]  Filtr prózni 2 [mBar]  \
# count   127547.000000          127547.000000
# mean         0.162250               0.157359
# std          0.030283               0.045060
# min          0.000318               0.000000
# 25%          0.153956               0.142941
# 50%          0.156981               0.158235
# 75%          0.160802               0.177059
# max          0.630632               1.000000
#
#        Grubosc pietki ukladu wlewowego [mm]     Kod formy   Koncentrat [%]  \
# count                         127547.000000  127547.000000   127547.000000
# mean                               0.000582       0.327348        0.434721
# std                                0.000041       0.252185        0.070168
# min                                0.000427       0.000000        0.000000
# 25%                                0.000565       0.250000        0.407407
# 50%                                0.000580       0.250000        0.444444
# 75%                                0.000610       0.500000        0.481481
# max                                0.001312       1.000000        0.962963
#
#        Max. cisnienie [Bar]  Max. predkosc wtrysku [m/s]  ...  \
# count         127547.000000                127547.000000  ...
# mean               0.361566                     0.366276  ...
# std                0.007857                     0.011194  ...
# min                0.336996                     0.320579  ...
# 25%                0.360806                     0.357808  ...
# 50%                0.360806                     0.368149  ...
# 75%                0.362637                     0.368149  ...
# max                1.000000                     1.000000  ...
#
#        Temperatura w obwodzie chlodzenia 20 [°C]  \
# count                              127547.000000
# mean                                    0.238632
# std                                     0.047816
# min                                     0.081633
# 25%                                     0.204082
# 50%                                     0.224490
# 75%                                     0.265306
# max                                     1.000000
#
#        Temperatura w obwodzie chlodzenia 6 [°C]  \
# count                             127547.000000
# mean                                   0.205392
# std                                    0.050867
# min                                    0.052632
# 25%                                    0.184211
# 50%                                    0.210526
# 75%                                    0.236842
# max                                    1.000000
#
#        Temperatura w obwodzie chlodzenia 7 [°C]  \
# count                             127547.000000
# mean                                   0.240263
# std                                    0.024355
# min                                    0.076923
# 25%                                    0.230769
# 50%                                    0.230769
# 75%                                    0.256410
# max                                    1.000000
#
#        Temperatura wody na wejsciu JetCool [°C]  Wartosc prózni 2 [mBar]  \
# count                             127547.000000            127547.000000
# mean                                   0.475740                 0.176073
# std                                    0.062934                 0.067748
# min                                    0.000000                 0.000000
# 25%                                    0.438303                 0.131403
# 50%                                    0.455013                 0.159243
# 75%                                    0.483290                 0.207684
# max                                    1.000000                 0.841314
#
#         Leakage_High  Wartosc próżni 1&3 corr  Filtr próżni 1&3 corr  \
# count  127547.000000            127547.000000          127547.000000
# mean        0.008225                 0.197310               0.390521
# std         0.026832                 0.070832               0.030902
# min         0.000000                 0.000000               0.000000
# 25%         0.001933                 0.170485               0.377841
# 50%         0.003200                 0.192722               0.386048
# 75%         0.006017                 0.225741               0.400253
# max         1.000000                 1.000000               1.000000
#
#        Profil próżni 1&3 corr  Termoregulator 3.1&3.2 corr
# count           127547.000000                127547.000000
# mean                 0.428958                     0.063142
# std                  0.051602                     0.006649
# min                  0.000000                     0.000000
# 25%                  0.415943                     0.062872
# 50%                  0.432912                     0.063721
# 75%                  0.446330                     0.064571
# max                  1.000000                     0.130841
#
# [8 rows x 49 columns]

# %% [markdown]
# # Dane wejścia i wyjścia

# %%
import random

class Status:
    GOOD = "GOOD"
    REPAIRABLE = "REPAIRABLE"
    NO_GOOD = "NO GOOD"
    
    
class Leakage:
    def __init__(self,value ):
        self.value = value
        self.leakage_status = self.get_leakage_status()
        
    def get_leakage_status(self):
        if self.value<=0.0125:
            return Status.GOOD
        elif self.value <=0.125:
            return Status.REPAIRABLE
        else:
            return Status.NO_GOOD


class LeakageContainer:
    def __init__(self,inputs, outputs):
        self.inputs = inputs
        self.outputs = outputs
        self.conected = self.connect()
        
        
    def connect(self):
        #return list(zip(self.inputs,self.outputs))
        #return inputs+outputs
        
        con_list = []
        for index in range (len(self.inputs)):
            con_list.append(self.inputs[index] + [self.outputs[index]] )
        return con_list
        
    def get_status(self):
        return [x.leakage_status for x in self.outputs]
    
    #def temp(self,x):
        #print(x)
        #return x[-1].leakage_status== Status.NO_GOOD
        
    
    def evenly_distribute(self):
        
        no_good = list(filter(lambda x: x[-1].leakage_status == Status.NO_GOOD ,self.conected))
        repairable = list(filter(lambda x: x[-1].leakage_status == Status.REPAIRABLE,self.conected))
        good= list(filter(lambda x: x[-1].leakage_status == Status.GOOD,self.conected))
        good_shrunk = good[:len(no_good)]
        rep_shrunk = repairable[:len(no_good)]
        self.conected = no_good+good_shrunk+rep_shrunk
        random.shuffle(self.conected)
        
        
        
        inputs=[]
        
        for x in self.conected:
            inputs.append(x[0:-1])
        
        
        outputs=[]
        
        for x in self.conected:
            outputs.append(x[-1])
        
        
        self.inputs = inputs
        self.outputs = outputs
        print(len(self.inputs))

# %%
#p=LeakageContainer(inputs1,outputs1)
#p.evenly_distribute()
#print(len(p.conected))
#print(len(p.inputs))
#print(len(p.outputs))

# %%
nemak = clean_nemak_raw.drop(['Leakage_High','LeakageHighStatus'],axis=1)
output = clean_nemak_raw['Leakage_High'].reset_index(drop=True)

# %%
#wyniki jako klasa Leakage
outputs1=[]
for index,row in clean_nemak_raw.iterrows():
    outputs1.append(Leakage(row['Leakage_High']))

inputs1 = nemak.values.tolist()

# %%
outputs1[3].leakage_status
# Out:
# 'GOOD'

# %%
output[3]
# Out:
# 0.001866697778296305

# %%
#współczynnik korelacji liniowej
corr_matrix = clean_nemak_raw.corr()

# %%
corr_matrix['Leakage_High'].sort_values(ascending = False)
# Out:
# Leakage_High                                 1.000000
# Predkosc 1. fazy wtrysku [m/s]               0.072746
# Temperatura w obwodzie chlodzenia 14 [°C]    0.065937
# Przeplyw w obwodzie chlodzenia  11 [l]       0.065800
# Temperatura w obwodzie chlodzenia 1 [°C]     0.053294
# Temperatura termoregulator 2.1 [°C]          0.051214
# Koncentrat [%]                               0.051009
# Temperatura w obwodzie chlodzenia 6 [°C]     0.048542
# Temperatura wody na wejsciu JetCool [°C]     0.040014
# Suw 2. fazy wtrysku [mm]                     0.032112
# Kod formy                                    0.030419
# Przeplyw w obwodzie chlodzenia  12 [l]       0.024152
# Temperatura w obwodzie chlodzenia 17 [°C]    0.023213
# Grubosc pietki ukladu wlewowego [mm]         0.019408
# Max. predkosc wtrysku [m/s]                  0.018188
# Termoregulator 3.1&3.2 corr                  0.016475
# Temperatura w obwodzie chlodzenia 13 [°C]    0.015727
# Temperatura w obwodzie chlodzenia 7 [°C]     0.015416
# Predkosc 2. fazy wtrysku [m/s]               0.014184
# Czas cyklu [s]                               0.011078
# Czas 2. fazy wtrysku [ms]                    0.001998
# Suw 1. fazy wtrysku [mm]                    -0.000174
# Poziom wody w JetCool [mm]                  -0.001416
# Przeplyw w obwodzie chlodzenia  7 [l]       -0.002112
# Temperatura w obwodzie chlodzenia 18 [°C]   -0.002402
# Przeplyw w obwodzie chlodzenia  13 [l]      -0.003040
# Shift                                       -0.004341
# Wartosc próżni 1&3 corr                     -0.006423
# Profil próżni 1&3 corr                      -0.007288
# Przeplyw w obwodzie chlodzenia  20 [l]      -0.008314
# Przeplyw w obwodzie chlodzenia  15 [l]      -0.008884
# Temperatura w obwodzie chlodzenia 15 [°C]   -0.010275
# Max. cisnienie [Bar]                        -0.011917
# Temperatura w obwodzie chlodzenia 11 [°C]   -0.014994
# Temperatura w obwodzie chlodzenia 20 [°C]   -0.023211
# Filtr próżni 1&3 corr                       -0.023424
# Temperatura termoregulator 2.2 [°C]         -0.024705
# Przeplyw w obwodzie chlodzenia  18 [l]      -0.025254
# Temperatura w obwodzie chlodzenia 12 [°C]   -0.028449
# Przeplyw w obwodzie chlodzenia  1 [l]       -0.030513
# Filtr prózni 2 [mBar]                       -0.030992
# Przeplyw w obwodzie chlodzenia  6 [l]       -0.038538
# Opóznienie multiplikacji [ms]               -0.039844
# Temperatura stopu [°C]                      -0.053362
# Profil prózni 2 [mBar]                      -0.057314
# Wartosc prózni 2 [mBar]                     -0.059589
# Przeplyw w obwodzie chlodzenia  14 [l]      -0.079651
# Przeplyw w obwodzie chlodzenia  17 [l]      -0.110627
# Czas 1. fazy wtrysku [ms]                   -0.119749
# Name: Leakage_High, dtype: float64

# %%
inputs1
# Out:
# [[1.0,
#   0.17509867240760674,
#   0.14960629545797513,
#   0.21286417633007998,
#   0.017058823529411765,
#   0.0006713969634546426,
#   0.0,
#   0.462962954786743,
#   0.3663003663003663,
#   0.35780765365547207,
#   0.001266891891891892,
#   0.34843205574912894,
#   0.4791666550251342,
#   0.35149863760217986,
#   0.09009546539379475,
#   0.46296296296296297,
#   0.3191489361702128,
#   0.34285714285714286,
#   0.425,
#   0.4827586206896552,
#   0.4482758620689655,
#   0.26229508196721313,
#   0.41935483870967744,
#   0.4791666666666667,
#   0.421875,
#   0.34285714285714286,
#   0.020072992700729927,
#   0.3591331269349845,
#   0.3778955189684368,
#   0.5136986301369864,
#   0.4864864864864865,
#   0.4146341463414634,
#   0.1724137931034483,
#   0.15384615384615385,
#   0.28,
#   0.24444444444444444,
#   0.2391304347826087,
#   0.13333333333333333,
#   0.2807017543859649,
#   0.5306122448979592,
#   0.3157894736842105,
#   0.28205128205128205,
#   0.4190231492295783,
#   0.08574610244988864,
#   0.22574123989218328,
#   0.47190656565656564,
#   0.5153906866614049,
#   0.06414613423959219],
#  [1.0,
#   0.15357014711158953,
#   0.14960629545797513,
#   0.15300110312219925,
#   0.012352941176470587,
#   0.0006103608758678569,
#   0.0,
#   0.37037036382939437,
#   0.3663003663003663,
#   0.3671147555211036,
#   0.001266891891891892,
#   0.34843205574912894,
#   0.5,
#   0.3528610354223433,
#   0.03997613365155131,
#   0.46296296296296297,
#   0.3191489361702128,
#   0.35714285714285715,
#   0.425,
#   0.4827586206896552,
#   0.46551724137931033,
#   0.26229508196721313,
#   0.43548387096774194,
#   0.4791666666666667,
#   0.421875,
#   0.34285714285714286,
#   0.016423357664233577,
#   0.
#  <__main__.Leakage at 0x162ae6abfc8>,
#  <__main__.Leakage at 0x162ae6ab088>,
#  <__main__.Leakage at 0x162ae6ab048>,
#  <__main__.Leakage at 0x162ae6ad0c8>,
#  <__main__.Leakage at 0x162ae6ad108>,
#  <__main__.Leakage at 0x162ae6ad148>,
#  <__main__.Leakage at 0x162ae6ad188>,
#  <__main__.Leakage at 0x162ae6ad1c8>,
#  <__main__.Leakage at 0x162ae6ad208>,
#  <__main__.Leakage at 0x162ae6ad248>,
#  <__main__.Leakage at 0x162ae6ad288>,
#  <__main__.Leakage at 0x162ae6ad2c8>,
#  <__main__.Leakage at 0x162ae6ad308>,
#  <__main__.Leakage at 0x162ae6ad348>,
#  <__main__.Leakage at 0x162ae6ad388>,
#  <__main__.Leakage at 0x162ae6ad3c8>,
#  <__main__.Leakage at 0x162ae6ad408>,
#  <__main__.Leakage at 0x162ae6ad448>,
#  <__main__.Leakage at 0x162ae6ad488>,
#  <__main__.Leakage at 0x162ae6ad4c8>,
#  <__main__.Leakage at 0x162ae6ad508>,
#  <__main__.Leakage at 0x162ae6ad548>,
#  <__main__.Leakage at 0x162ae6ad588>,
#  <__main__.Leakage at 0x162ae6ad5c8>,
#  <__main__.Leakage at 0x162ae6ad608>,
#  <__main__.Leakage at 0x162ae6ad648>,
#  <__main__.Leakage at 0x162ae6ad688>,
#  <__main__.Leakage at 0x162ae6ad6c8>,
#  <__main__.Leakage at 0x162ae6ad708>,
#  <__main__.Leakage at 0x162ae6ad748>,
#  <__main__.Leakage at 0x162ae6ad788>,
#  ...]

# %%
K=
# Out:
#   File "<ipython-input-24-fd50be2fd4db>", line 1
#     K=
#       ^
# SyntaxError: invalid syntax

# %%
x_test
# Out:
# StandardScaler()

# %% [markdown]
# # Trenowanie modelu

# %%
#dzielenie modelu
from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(inputs1, outputs1, test_size=0.33,random_state=42) #random_state=42
train_container = LeakageContainer(X_train,y_train)
test_container = LeakageContainer(X_test,y_test)

# %%
len(train_container.outputs)
# Out:
# 85456

# %%
print(len(X_train))
print(len(y_train))
# Out:
# 85456
# 85456

# %%
print(len(X_test)) #input
print(len(y_test))#output
# Out:
# 42091
# 42091

# %%
print(len(train_container.inputs[150]))
#inputs1
# Out:
# 48

# %%
# train container
a=0
b=0
c=0
for y in y_train:
    if y.leakage_status == 'GOOD':
        a+=1
    elif y.leakage_status == 'REPAIRABLE':
        b+=1
    elif y.leakage_status == 'NO GOOD':
        c+=1
print(a,b,c)
# Out:
# 76395 8544 517

# %%
# test container
a=0
b=0
c=0
for y in y_test:
    if y.leakage_status == 'GOOD':
        a+=1
    elif y.leakage_status == 'REPAIRABLE':
        b+=1
    elif y.leakage_status == 'NO GOOD':
        c+=1
print(a,b,c)
# Out:
# 37671 4157 263

# %%
76395+8544+517
# Out:
# 85456

# %%
train_container.evenly_distribute()
test_container.evenly_distribute()
# Out:
# 1551
# 789

# %%
len(train_container.outputs)
# Out:
# 1551

# %%
a=0
b=0
c=0
for y in train_container.outputs:
    if y.leakage_status == 'GOOD':
        a+=1
    elif y.leakage_status == 'REPAIRABLE':
        b+=1
    elif y.leakage_status == 'NO GOOD':
        c+=1
print(a,b,c)
# Out:
# 517 517 517

# %%
a=0
b=0
c=0
for y in test_container.outputs:
    if y.leakage_status == 'GOOD':
        a+=1
    elif y.leakage_status == 'REPAIRABLE':
        b+=1
    elif y.leakage_status == 'NO GOOD':
        c+=1
print(a,b,c)
# Out:
# 263 263 263

# %%
print(train_container.inputs[1])
print(test_container.inputs[1])
# Out:
# [1.0, 0.1689989235737352, 0.1732283464566929, 0.15538925773538692, 0.13117647058823528, 0.0005493247882810712, 0.5, 0.35185184122276586, 0.3498168498168498, 0.35780765365547207, 0.0014076576576576576, 0.3902439024390244, 0.4791666550251342, 0.3474114051631751, 0.07040572792362769, 0.5, 0.2553191489361702, 0.14285714285714285, 0.725, 0.6379310344827587, 0.5172413793103449, 0.3114754098360656, 0.4838709677419355, 0.4375, 0.453125, 0.42857142857142855, 0.01824817518248175, 0.3761609907120743, 0.3773567897282949, 0.4657534246575342, 0.49324324324324326, 0.17073170731707318, 0.20689655172413793, 0.23076923076923078, 0.16, 0.15555555555555556, 0.15217391304347827, 0.13333333333333333, 0.24561403508771928, 0.2653061224489796, 0.13157894736842105, 0.23076923076923078, 0.45372747882254716, 0.10022271714922049, 0.52088948787062, 0.3096590909090909, 0.40173638516179955, 0.06287170773152082]
# [1.0, 0.14388231072838178, 0.15748031496062992, 0.154274790441279, 0.1811764705882353, 0.0006561379415579462, 0.75, 0.4074074090426514, 0.36446886446886445, 0.34953465230336506, 0.0019707207207207205, 0.4930313588850174, 0.5, 0.3446866121214157, 0.11217183770883055, 0.4444444444444444, 0.44680851063829785, 0.12857142857142856, 0.55, 0.6206896551724138, 0.39655172413793105, 0.29508196721311475, 0.532258064516129, 0.7916666666666666, 0.4375, 0.4, 0.021897810218978103, 0.3591331269349845, 0.3789728678506654, 0.4863013698630137, 0.4864864864864865, 0.21951219512195122, 0.20689655172413793, 0.20512820512820512, 0.2, 0.15555555555555556, 0.21739130434782608, 0.1111111111111111, 0.22807017543859648, 0.1836734693877551, 0.18421052631578946, 0.20512820512820512, 0.4190231492295783, 0.22160356347438753, 0.22304582210242588, 0.4059343434343434, 0.4928966061562747, 0.06457094307561598]

# %%
ys_train=train_container.get_status()
ys_test=test_container.get_status()

print(ys_test.count(Status.GOOD))
print(ys_test.count(Status.NO_GOOD))
print(ys_test.count(Status.REPAIRABLE))
print(len(ys_test))
print(len(test_container.inputs))
print(ys_train.count(Status.GOOD))
print(ys_train.count(Status.NO_GOOD))
print(ys_train.count(Status.REPAIRABLE))
print(len(train_container.outputs))
print(len(ys_train))
# Out:
# 263
# 263
# 263
# 789
# 789
# 517
# 517
# 517
# 1551
# 1551

# %%
#trenowanie modeli
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x_train = scaler.fit_transform(train_container.inputs)
x_test = scaler.transform(test_container.inputs)

# %%
print (x_train[1])
print(train_container.inputs[1])
# Out:
# [ 1.14541961 -1.17637687  0.44191199 -0.14825781  0.06519316 -0.86018829
#  -1.35483282  0.81537528  1.02974076  1.1296769  -1.00387107  0.77388278
#   0.88127544 -0.46514724 -0.95247295 -0.39012873  0.64674055  0.22990717
#  -0.79027574 -1.65733376 -1.40357583  0.38190423 -0.37254755 -0.04852718
#  -1.13757907 -0.39801652 -1.10280771  1.05379921  0.07137368  0.76717245
#   0.49533088  0.67553031 -0.12897689 -0.40736325  0.99142339  1.01822946
#   0.74570062 -0.20484404  0.67026121  0.1648981   0.97322208  0.62021439
#  -0.19050769 -0.32123868 -0.20102437 -0.37086015 -0.42689963 -0.01244704]
# [1.0, 0.1689989235737352, 0.1732283464566929, 0.15538925773538692, 0.13117647058823528, 0.0005493247882810712, 0.5, 0.35185184122276586, 0.3498168498168498, 0.35780765365547207, 0.0014076576576576576, 0.3902439024390244, 0.4791666550251342, 0.3474114051631751, 0.07040572792362769, 0.5, 0.2553191489361702, 0.14285714285714285, 0.725, 0.6379310344827587, 0.5172413793103449, 0.3114754098360656, 0.4838709677419355, 0.4375, 0.453125, 0.42857142857142855, 0.01824817518248175, 0.3761609907120743, 0.3773567897282949, 0.4657534246575342, 0.49324324324324326, 0.17073170731707318, 0.20689655172413793, 0.23076923076923078, 0.16, 0.15555555555555556, 0.15217391304347827, 0.13333333333333333, 0.24561403508771928, 0.2653061224489796, 0.13157894736842105, 0.23076923076923078, 0.45372747882254716, 0.10022271714922049, 0.52088948787062, 0.3096590909090909, 0.40173638516179955, 0.06287170773152082]

# %%
#klasyfikacja # zapytaj profesora

# %% [markdown]
# # SVM

# %%
from sklearn import svm

clf_svm = svm.SVC(kernel='linear')

clf_svm.fit(x_train,ys_train)
# Out:
# SVC(kernel='linear')

# %%
clf_svm.predict([x_test[1]])
# Out:
# array(['REPAIRABLE'], dtype='<U10')

# %%
test_container.outputs[1].value
# Out:
# 0.09223487058117635

# %% [markdown]
# # Decision tree

# %%
from sklearn.tree import DecisionTreeClassifier

clf_dec = DecisionTreeClassifier()

clf_dec.fit(x_train,ys_train)
# Out:
# DecisionTreeClassifier()

# %%
clf_dec.predict([x_test[1]])
# Out:
# array(['REPAIRABLE'], dtype='<U10')

# %%
test_container.outputs[1].value
# Out:
# 0.09223487058117635

# %% [markdown]
# # naive bayes

# %%
from sklearn.naive_bayes import GaussianNB

clf_gnb = GaussianNB()

clf_gnb.fit(x_train,ys_train)
# Out:
# GaussianNB()

# %%
clf_gnb.predict([x_test[1]])
# Out:
# array(['GOOD'], dtype='<U10')

# %% [markdown]
# # logistic regression

# %%
from sklearn.linear_model import LogisticRegression

clf_log = LogisticRegression()

clf_log.fit(x_train,ys_train)
# Out:
# LogisticRegression()

# %%
clf_log.predict([x_test[1]])
# Out:
# array(['REPAIRABLE'], dtype='<U10')

# %%
from sklearn.neighbors import KNeighborsClassifier

clf_knn=KNeighborsClassifier()

clf_knn.fit(x_train,ys_train)
# Out:
# KNeighborsClassifier()

# %%
clf_knn.predict([x_test[1]])
# Out:
# array(['REPAIRABLE'], dtype='<U10')

# %%
from sklearn.neural_network import MLPClassifier

clf_nt =MLPClassifier()

clf_nt.fit(x_train,ys_train)
# Out:
# C:\Users\patry\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:617: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# MLPClassifier()

# %%
clf_nt.predict([x_test[1]])
# Out:
# array(['REPAIRABLE'], dtype='<U10')

# %% [markdown]
# # Analiza modeli #1

# %%
#średnia trafność
print(clf_svm.score(x_test,ys_test))
print(clf_dec.score(x_test,ys_test))
print(clf_gnb.score(x_test,ys_test))
print(clf_log.score(x_test,ys_test))
print(clf_knn.score(x_test,ys_test))
print(clf_nt.score(x_test,ys_test))
# Out:
# 0.5792141951837769
# 0.46261089987325726
# 0.5525982256020279
# 0.5792141951837769
# 0.5602027883396705
# 0.550063371356147

# %%
#f1 score
from sklearn.metrics import f1_score

f1_score(ys_test,clf_svm.predict(x_test), average=None,labels=[Status.GOOD,Status.REPAIRABLE,Status.NO_GOOD])
# Out:
# array([0.59809524, 0.50096339, 0.63670412])

# %%
f1_score(ys_test,clf_dec.predict(x_test), average=None,labels=[Status.GOOD,Status.REPAIRABLE,Status.NO_GOOD])
# Out:
# array([0.47817837, 0.38297872, 0.52434457])

# %%
f1_score(ys_test,clf_gnb.predict(x_test), average=None,labels=[Status.GOOD,Status.REPAIRABLE,Status.NO_GOOD])
# Out:
# array([0.5583174 , 0.48837209, 0.60853432])

# %%
f1_score(ys_test,clf_log.predict(x_test), average=None,labels=[Status.GOOD,Status.REPAIRABLE,Status.NO_GOOD])
# Out:
# array([0.62222222, 0.48594378, 0.62222222])

# %%
f1_score(ys_test,clf_knn.predict(x_test), average=None,labels=[Status.GOOD,Status.REPAIRABLE,Status.NO_GOOD])
# Out:
# array([0.5970696 , 0.46861925, 0.60288809])

# %%
f1_score(ys_test,clf_nt.predict(x_test), average=None,labels=[Status.GOOD,Status.REPAIRABLE,Status.NO_GOOD])
# Out:
# array([0.57539683, 0.48175182, 0.59695817])

# %%
ys_train.count(Status.GOOD)
# Out:
# 517

# %%
ys_train.count(Status.REPAIRABLE)
# Out:
# 517

# %%
ys_train.count(Status.NO_GOOD)
# Out:
# 517

# %% [markdown]
# # Głosowanie

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB

clf_log2= LogisticRegression()
clf_rnd= RandomForestClassifier()
clf_gnb2 = GaussianNB()
clf_knn2 = KNeighborsClassifier()
clf_nt2 = clf_nt

voting_clf=VotingClassifier(
    estimators=[('lr',clf_log2),('rf',clf_rnd),('gnb',clf_gnb2),('knn',clf_knn2),('nt',clf_nt2)],
    voting='hard')
voting_clf.fit(x_train,ys_train)
# Out:
# C:\Users\patry\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:617: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# VotingClassifier(estimators=[('lr', LogisticRegression()),
#                              ('rf', RandomForestClassifier()),
#                              ('gnb', GaussianNB()),
#                              ('knn', KNeighborsClassifier()),
#                              ('nt', MLPClassifier())])

# %%
from sklearn.metrics import accuracy_score
for clf in (clf_log2,clf_rnd,clf_gnb2,clf_knn2,clf_nt2,voting_clf):
    clf.fit(x_train,ys_train)
    y_pred = clf.predict(x_test)
    print(clf.__class__.__name__,accuracy_score(ys_test,y_pred))
# Out:
# LogisticRegression 0.5792141951837769
# RandomForestClassifier 0.5792141951837769
# GaussianNB 0.5525982256020279
# KNeighborsClassifier 0.5602027883396705
# C:\Users\patry\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:617: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# MLPClassifier 0.5564005069708492
# VotingClassifier 0.5779467680608364
# C:\Users\patry\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:617: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)

# %%
f1_score(ys_test,voting_clf.predict(x_test), average=None,labels=[Status.GOOD,Status.REPAIRABLE,Status.NO_GOOD])
# Out:
# array([0.60329068, 0.4875    , 0.63157895])

# %% [markdown]
# # Zwiększanie dokładności

# %%
from sklearn.model_selection import GridSearchCV

parameters = {'kernel':('linear','rbf'), 'C':(1,4,8,16,32)}

svc= svm.SVC()
clf=GridSearchCV(svc, parameters, cv=5)
clf.fit(x_train,ys_train)
# Out:
# GridSearchCV(cv=5, estimator=SVC(),
#              param_grid={'C': (1, 4, 8, 16, 32), 'kernel': ('linear', 'rbf')})

# %%
print(clf.score(x_test,ys_test))
# Out:
# 0.5741444866920152

# %%
print(clf_svm.score(x_test,ys_test))
# Out:
# 0.5792141951837769

# %% [markdown]
# # zapisywanie

# %%
import pickle

with open("voting.pkl",'wb') as f:
    pickle.dump(voting_clf,f)

# %%
#ładowanie modelu
with open("voting.pkl",'rb') as f:
    loaded_clf = pickle.load(f)

# %%
loaded_clf.predict([x_test[0]])
# Out:
# array(['GOOD'], dtype='<U10')

# %% [markdown]
# # CONFUSION MATRIX

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd
import matplotlib as plt


y_pred = loaded_clf.predict(x_test)

labels =[Status.GOOD,Status.REPAIRABLE,Status.NO_GOOD]
labels2 =[Status.NO_GOOD,Status.REPAIRABLE,Status.GOOD]
cm=confusion_matrix (ys_test,y_pred, labels=labels)
df_cm = pd.DataFrame(cm,index=labels, columns=labels)

sn.heatmap(df_cm,annot=True,fmt='d')

# %% [markdown]
# # CROSS VALIDATION

# %%
from sklearn.model_selection import cross_val_score

cross_val_score(loaded_clf,x_train,ys_train,cv=7,scoring='accuracy')
# Out:
# C:\Users\patry\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:617: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\patry\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:617: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\patry\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:617: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\patry\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:617: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\patry\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:617: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\patry\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:617: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\patry\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:617: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# array([0.58108108, 0.57657658, 0.54054054, 0.57657658, 0.53846154,
#        0.52036199, 0.58823529])

# %%
len(train_container.inputs)
# Out:
# 1551

# %% [markdown]
# # z całości danych

# %%
all_container = LeakageContainer(inputs1,outputs1)
ys_all=all_container.get_status()

x_all = scaler.transform(all_container.inputs)

# %%
f1_score(ys_all,loaded_clf.predict(x_all), average=None,labels=[Status.GOOD,Status.REPAIRABLE,Status.NO_GOOD])
# Out:
# array([0.77003701, 0.27385716, 0.05647364])

# %%
y_pred2 = loaded_clf.predict(x_all)

labels =[Status.GOOD,Status.REPAIRABLE,Status.NO_GOOD]
labels2 =[Status.NO_GOOD,Status.REPAIRABLE,Status.GOOD]
cm=confusion_matrix (ys_all,y_pred2, labels=labels)
df_cm = pd.DataFrame(cm,index=labels, columns=labels)

sn.heatmap(df_cm,annot=True,fmt='d')

# %% [markdown]
# # Wykorzystanie wag klas

# %%
from sklearn.linear_model import LogisticRegression

#lr = LogisticRegression(solver='newton-cg', class_weight='balanced')
clf_log2= LogisticRegression(class_weight='balanced')
clf_rnd= RandomForestClassifier(class_weight='balanced')
clf_gnb2 = GaussianNB()
clf_knn2 = KNeighborsClassifier()
clf_nt2 = MLPClassifier()

voting_clf1=VotingClassifier(
    estimators=[('lr',clf_log2),('rf',clf_rnd),('gnb',clf_gnb2),('knn',clf_knn2),('nt',clf_nt2)],
    voting='hard')


train_container_wage = LeakageContainer(X_train,y_train)
test_container_wage = LeakageContainer(X_test,y_test)


ys_train_wage=train_container_wage.get_status()
ys_test_wage=test_container_wage.get_status()

x_train_wage = scaler.transform(train_container_wage.inputs)
x_test_wage = scaler.transform(test_container_wage.inputs)

# %%
voting_clf1.fit(x_train_wage, ys_train_wage)
# Out:
# C:\Users\patry\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\patry\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:617: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# VotingClassifier(estimators=[('lr',
#                               LogisticRegression(class_weight='balanced')),
#                              ('rf',
#                               RandomForestClassifier(class_weight='balanced')),
#                              ('gnb', GaussianNB()),
#                              ('knn', KNeighborsClassifier()),
#                              ('nt', MLPClassifier())])

# %%
f1_test = f1_score(ys_test_wage,voting_clf1.predict(x_test_wage), average=None,labels=[Status.GOOD,Status.REPAIRABLE,Status.NO_GOOD])
print('The f1 score for the testing data:', f1_test)
# Out:
# The f1 score for the testing data: [0.94684373 0.27282569 0.1754386 ]

# %%
y_pred3 = voting_clf1.predict(x_all)

labels =[Status.GOOD,Status.REPAIRABLE,Status.NO_GOOD]
labels2 =[Status.NO_GOOD,Status.REPAIRABLE,Status.GOOD]
cm=confusion_matrix (ys_all,y_pred3, labels=labels)
df_cm = pd.DataFrame(cm,index=labels, columns=labels)

sn.heatmap(df_cm,annot=True,fmt='d')

# %% [markdown]
# technika smote

# %%
from imblearn.over_sampling import SMOTE

sm = SMOTE(random_state=42)


sm_container = LeakageContainer(inputs1,outputs1)

ys_sm=sm_container.get_status()


X_sm, y_sm = sm.fit_resample(sm_container.inputs,ys_sm)

# %%
X_train,X_test,y_train,y_test = train_test_split(X_sm,y_sm, test_size=0.33,random_state=42)

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

clf_log3= LogisticRegression()
clf_rnd1= RandomForestClassifier()
clf_gnb3 = GaussianNB()
clf_knn3 = KNeighborsClassifier()
clf_nt3 = MLPClassifier()

voting_sm=VotingClassifier(
    estimators=[('lr',clf_log3),('rf',clf_rnd1),('gnb',clf_gnb3),('knn',clf_knn3),('nt',clf_nt3)],
    voting='hard')


voting_sm.fit(X_train,y_train)
# Out:
# C:\Users\patry\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\patry\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:617: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-117-1674a6929867> in <module>
#      16
#      17 voting_sm.fit(X_train,y_train)
# ---> 18 pred = model_sm.predict(X_test)
#      19
#
# NameError: name 'model_sm' is not defined

# %%
pred = voting_sm.predict(X_test)

# %%
f1_test = f1_score(y_test,voting_sm.predict(X_test), average=None,labels=[Status.GOOD,Status.REPAIRABLE,Status.NO_GOOD])
print('The f1 score for the testing data:', f1_test)
# Out:
# The f1 score for the testing data: [0.83892218 0.84489505 0.96678342]

# %%
# dane testowe
y_pred_sm = pred

labels =[Status.GOOD,Status.REPAIRABLE,Status.NO_GOOD]
labels2 =[Status.NO_GOOD,Status.REPAIRABLE,Status.GOOD]
cm=confusion_matrix (y_test,y_pred_sm, labels=labels)
df_cm = pd.DataFrame(cm,index=labels, columns=labels)

sn.heatmap(df_cm,annot=True,fmt='d')

# %% [markdown]
# test na całuych danych

# %%
y_pred4 = voting_sm.predict(x_all)

labels =[Status.GOOD,Status.REPAIRABLE,Status.NO_GOOD]
labels2 =[Status.NO_GOOD,Status.REPAIRABLE,Status.GOOD]
cm=confusion_matrix (ys_all,y_pred4, labels=labels)
df_cm = pd.DataFrame(cm,index=labels, columns=labels)

sn.heatmap(df_cm,annot=True,fmt='d')

# %%
f1_test = f1_score(ys_all,y_pred4, average=None,labels=[Status.GOOD,Status.REPAIRABLE,Status.NO_GOOD])
print('The f1 score for the testing data:', f1_test)
# Out:
# The f1 score for the testing data: [0.82261345 0.39469403 0.22479803]

# %%
len(x_all)
# Out:
# 127547

# %%
from sklearn.model_selection import GridSearchCV, StratifiedKFold
lr = LogisticRegression(solver='newton-cg')

#Setting the range for class weights
weights = np.linspace(0.0,0.99,200)

#Creating a dictionary grid for grid search
param_grid = {'class_weight': [{0:x, 1:1.0-x} for x in weights]}

#Fitting grid search to the train data with 5 folds
gridsearch = GridSearchCV(estimator= lr, 
                          param_grid= param_grid,
                          cv=StratifiedKFold(), 
                          n_jobs=-1, 
                          scoring='f1', 
                          verbose=2).fit(train_container_wage.inputs, ys_train_wage)
# Out:
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=-1)]: Done 146 tasks      | elapsed: 17.0min
# [Parallel(n_jobs=-1)]: Done 349 tasks      | elapsed: 44.3min
# [Parallel(n_jobs=-1)]: Done 632 tasks      | elapsed: 77.8min
# [Parallel(n_jobs=-1)]: Done 1000 out of 1000 | elapsed: 121.4min finished
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-310-e75c85976ac1> in <module>
#      14                           n_jobs=-1,
#      15                           scoring='f1',
# ---> 16                           verbose=2).fit(train_container_wage.inputs, ys_train_wage)
#      17
#      18 #Ploting the score for different values of weight
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     737             refit_start_time = time.time()
#     738             if y is not None:
# --> 739                 self.best_estimator_.fit(X, y, **fit_params)
#     740             else:
#     741                 self.best_estimator_.fit(X, **fit_params)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py in fit(self, X, y, sample_weight)
#    1599                       penalty=penalty, max_squared_sum=max_squared_sum,
#    1600                       sample_weight=sample_weight)
# -> 1601             for class_, warm_start_coef_ in zip(classes_, warm_start_coef))
#    1602
#    1603         fold_coefs_, _, n_iter_ = zip(*fold_coefs_)
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1002             # remaining jobs.
#    1003             self._iterating = False
# -> 1004             if self.dispatch_one_batch(iterator):
#    1005                 self._iterating = self._original_iterator is not None
#    1006
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     833                 return False
#     834             else:
# --> 835                 self._dispatch(tasks)
#     836                 return True
#     837
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     752         with self._lock:
#     753             job_idx = len(self._jobs)
# --> 754             job = self._backend.apply_async(batch, callback=cb)
#     755             # A job can complete so quickly than its callback is
#     756             # called before we get here, causing self._jobs to
#
# ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     207     def apply_async(self, func, callback=None):
#     208         """Schedule a func to be run"""
# --> 209         result = ImmediateResult(func)
#     210         if callback:
#     211             callback(result)
#
# ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     588         # Don't delay the application, to avoid keeping the input
#     589         # arguments in memory
# --> 590         self.results = batch()
#     591
#     592     def get(self):
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py in _logistic_regression_path(X, y, pos_class, Cs, fit_intercept, max_iter, tol, verbose, solver, coef, class_weight, dual, penalty, intercept_scaling, multi_class, random_state, check_input, max_squared_sum, sample_weight, l1_ratio)
#     841     le = LabelEncoder()
#     842     if isinstance(class_weight, dict) or multi_class == 'multinomial':
# --> 843         class_weight_ = compute_class_weight(class_weight, classes, y)
#     844         sample_weight *= class_weight_[le.fit_transform(y)]
#     845
#
# ~\anaconda3\lib\site-packages\sklearn\utils\class_weight.py in compute_class_weight(class_weight, classes, y)
#      63             i = np.searchsorted(classes, c)
#      64             if i >= len(classes) or classes[i] != c:
# ---> 65                 raise ValueError("Class label {} not present.".format(c))
#      66             else:
#      67                 weight[i] = class_weight[c]
#
# ValueError: Class label 0 not present.

# %%
#Ploting the score for different values of weight
sns.set_style('whitegrid')
plt.figure(figsize=(12,8))
weigh_data = pd.DataFrame({ 'score': gridsearch.cv_results_['mean_test_score'], 'weight': (1- weights)})
sns.lineplot(weigh_data['weight'], weigh_data['score'])
plt.xlabel('Weight for class 1')
plt.ylabel('F1 score')
plt.xticks([round(i/10,1) for i in range(0,11,1)])
plt.title('Scoring for different class weights', fontsize=24)

# %%
#importing and training the model
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(solver='newton-cg', class_weight={0: 0.06467336683417085, 1: 0.9353266331658292})
lr.fit(x_train, y_train)

# Predicting on the test data
pred_test = lr.predict(x_test)

#Calculating and printing the f1 score 
f1_test = f1_score(y_test, pred_test)
print('The f1 score for the testing data:', f1_test)

# %%
#sprawdzanie modelu

from sklearn.model_selection import cross_val_score

lin_scores = cross_val_score(lin_reg,nemak,output,
                            scoring='neg_mean_squared_error',cv=10)

lin_rmse_scores = np.sqrt(-lin_scores)

display_scores(lin_rmse_scores)
# Out:
# Wyniki:  [0.01322424 0.01642396 0.02120496 0.01897215 0.02023691 0.01213451
#  0.01244873 0.06187792 0.03358056 0.01751582]
# Średnia:  0.02276197484648885
# Odchylenie standardowe:  0.01431163446169649

# %%
test_set_x=test_container.outputs
test_set_y= test_container.inputs

w=clf_dec.predict(test_container.inputs)

# %%
x = range(2340)
print (len(test_set_y))
print(len(w))
# Out:
# 2340
# 2340

# %%
plt.scatter(x,w)

# %%
plt.scatter(x,test_set_y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-180-4d88c28efe4e> in <module>
# ----> 1 plt.scatter(x,test_set_y)
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2846         verts=verts, edgecolors=edgecolors,
#    2847         plotnonfinite=plotnonfinite, **({"data": data} if data is not
# -> 2848         None else {}), **kwargs)
#    2849     sci(__ret)
#    2850     return __ret
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1597     def inner(ax, *args, data=None, **kwargs):
#    1598         if data is None:
# -> 1599             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1600
#    1601         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, **kwargs)
#    4441         y = np.ma.ravel(y)
#    4442         if x.size != y.size:
# -> 4443             raise ValueError("x and y must be the same size")
#    4444
#    4445         if s is None:
#
# ValueError: x and y must be the same size

# %%
plt.scatter(test_set_y,w)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-183-0a7a293d4f15> in <module>
# ----> 1 plt.scatter(test_set_y,w)
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2846         verts=verts, edgecolors=edgecolors,
#    2847         plotnonfinite=plotnonfinite, **({"data": data} if data is not
# -> 2848         None else {}), **kwargs)
#    2849     sci(__ret)
#    2850     return __ret
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1597     def inner(ax, *args, data=None, **kwargs):
#    1598         if data is None:
# -> 1599             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1600
#    1601         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, **kwargs)
#    4441         y = np.ma.ravel(y)
#    4442         if x.size != y.size:
# -> 4443             raise ValueError("x and y must be the same size")
#    4444
#    4445         if s is None:
#
# ValueError: x and y must be the same size

# %% [markdown]
# # Ocena modelu

# %%
X_test = test_set.drop(['Leakage_High','LeakageHighStatus'],axis=1)
y_test = test_set['Leakage_High']

final_predictions = lin_reg.predict(X_test)

final_mse = mean_squared_error(y_test,final_predictions)
final_rmse = np.sqrt(final_mse)

final_rmse
# Out:
# 0.0248600760970223

# %% [markdown]
# # ---------------------------------------------------------------------------------
